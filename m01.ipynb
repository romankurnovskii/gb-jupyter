# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 121)
k1 = 1
y1 = np.cos(k1 * x)
k2 = 2
y2 = np.cos(k2 * x)
plt.plot(x, y1, x, y2)
plt.legend(('k=1', 'k=2'), title='y(k,x)=cos(k*x)', loc=1)
